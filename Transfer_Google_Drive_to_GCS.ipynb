# %% [markdown]
# <a href="https://colab.research.google.com/github/sondreskarsten/pythonxy/blob/master/Transfer_Google_Drive_to_GCS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transferring data from Google Drive to Google Cloud Storage
# This example shows how to transfer files from your Google Drive to a Google Cloud Storage project. We mount Google Drive using the google colab tools which requires authenticating in a separate brower window. Then we authenticate and connect our Google Cloud Storage project, list all buckets, and start copying files from Google Drive to our bucket.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()

project_id = 'Booth drive'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# ERROR: (gcloud.config.set) unrecognized arguments: drive
#
# To search the help text of gcloud commands, run:
#   gcloud help -- SEARCH_TERMS
# You are attempting to perform an operation that requires a project id, with none configured. Please re-run gsutil config and make sure to follow the instructions for finding and entering your default project id.

# %%
from google.cloud import storage
import json

project_id = "sondreskarsten-d7d14"
bucket_name = "sondre_brreg_data"
service_account_key_path = "/content/sondreskarsten-d7d14-8486be2d085b.json"

storage_client = storage.Client.from_service_account_json(service_account_key_path)
bucket = storage_client.bucket(bucket_name)

def upload_to_booth(local_file_path, gcs_filename):
    blob = bucket.blob(f"booth/{gcs_filename}")
    blob.upload_from_filename(local_file_path)

# Replace '/content/drive/My Drive/your_file.csv' with the actual path to your file in Google Drive
upload_to_booth("/content/drive/My Drive/your_file.csv", "remote_file.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3432714579.py in <cell line: 0>()
#      14
#      15 # Replace '/content/drive/My Drive/your_file.csv' with the actual path to your file in Google Drive
# ---> 16 upload_to_booth("/content/drive/My Drive/your_file.csv", "remote_file.csv")
#
# /tmp/ipython-input-3432714579.py in upload_to_booth(local_file_path, gcs_filename)
#      11 def upload_to_booth(local_file_path, gcs_filename):
#      12     blob = bucket.blob(f"booth/{gcs_filename}")
# ---> 13     blob.upload_from_filename(local_file_path)
#      14
#      15 # Replace '/content/drive/My Drive/your_file.csv' with the actual path to your file in Google Drive
#
# /usr/lib/python3.12/contextlib.py in inner(*args, **kwds)
#      79         def inner(*args, **kwds):
#      80             with self._recreate_cm():
# ...

# %%
file_id = "1dUGzQfhxInZuzPbNEMUAWJf459DLUsol"
output_path = "/content/sondreskarsten-d7d14-8486be2d085b.json"
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

import requests

response = requests.get(download_url)
response.raise_for_status()  # Raise an exception for bad status codes
with open(output_path, 'wb') as f:
    f.write(response.content)

print(f"Downloaded file to {output_path}")
# Out:
# Downloaded file to /content/sondreskarsten-d7d14-8486be2d085b.json
